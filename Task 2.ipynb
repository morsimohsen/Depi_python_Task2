# %%
! pip install xlrd
! pip install openpyxl
# Out:
# Looking in indexes: https://aws:****@tactful-409160330780.d.codeartifact.eu-west-1.amazonaws.com/pypi/ucx-pip/simple/
# ...
# Looking in indexes: https://aws:****@tactful-409160330780.d.codeartifact.eu-west-1.amazonaws.com/pypi/ucx-pip/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 690.4 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read Energy Indicators and Apply EDA On it.

# %%
energy = pd.read_excel("Energy Indicators.xls", header=None, skipfooter=38, skiprows=18)

# %%
energy.head()
# Out:
#     0               1               2     3    4           5
# 0 NaN     Afghanistan     Afghanistan   321   10   78.669280
# 1 NaN         Albania         Albania   102   35  100.000000
# 2 NaN         Algeria         Algeria  1959   51    0.551010
# 3 NaN  American Samoa  American Samoa   ...  ...    0.641026
# 4 NaN         Andorra         Andorra     9  121   88.695650

# %%
# Show the 5 last rows of the imoperted data
energy.tail()
# Out:
#       0                          1                          2     3   4  \
# 222 NaN                   Viet Nam                   Viet Nam  2554  28
# 223 NaN  Wallis and Futuna Islands  Wallis and Futuna Islands     0  26
# 224 NaN                      Yemen                      Yemen   344  13
# 225 NaN                     Zambia                     Zambia   400  26
# 226 NaN                   Zimbabwe                   Zimbabwe   480  32
#
#             5
# 222  45.32152
# 223   0.00000
# 224   0.00000
# 225  99.71467
# 226  52.53612

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       227 non-null    object
#  2   2       227 non-null    object
#  3   3       227 non-null    object
#  4   4       227 non-null    object
#  5   5       227 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 10.8+ KB

# %%
# Drop the first column that contains null 
energy.drop(energy.columns[0], axis=1, inplace=True)

# %%
energy.head()
# Out:
#                 1               2     3    4           5
# 0     Afghanistan     Afghanistan   321   10   78.669280
# 1         Albania         Albania   102   35  100.000000
# 2         Algeria         Algeria  1959   51    0.551010
# 3  American Samoa  American Samoa   ...  ...    0.641026
# 4         Andorra         Andorra     9  121   88.695650

# %%
# also get rid of data in first column that duplacted
energy.drop(energy.columns[0], axis=1, inplace=True)

# %%
# Rename the columns:

# Create list contains the needed names:
columns_list = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']

# Assign the culomns name to the dataframe:
energy.columns = columns_list

# %%
energy.head()
# Out:
#           Country Energy Supply Energy Supply per Capita  % Renewable
# 0     Afghanistan           321                       10    78.669280
# 1         Albania           102                       35   100.000000
# 2         Algeria          1959                       51     0.551010
# 3  American Samoa           ...                      ...     0.641026
# 4         Andorra             9                      121    88.695650

# %%
energy["Energy Supply"] = energy["Energy Supply"].replace(r'\.*', np.nan, regex=True)
# Out:
# /tmp/ipykernel_308746/2381188699.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   energy["Energy Supply"] = energy["Energy Supply"].replace(r'\.*', np.nan, regex=True)

# %%
# Convert Energy Supply to gigajoules (there are 1,000,000 gigajoules in a petajoule). 
energy['Energy Supply'] *= 1000000

# %%
# Replace the cells of "..." value with np.nans 
energy.replace('...', np.nan, inplace=True)
# Out:
# /tmp/ipykernel_308746/1711703656.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   energy.replace('...', np.nan, inplace=True)

# %%
# check the uniqe values in countries
energy["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia1', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China2',
#        'China, Hong Kong Special Administrative Region3',
#        'China, Macao Special Administrative Region4', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
# ...

# %%
# Replace required countries names:
energy['Country'] = energy['Country'].replace(to_replace="Republic of Korea", value="South Korea", regex=False)
energy['Country'] = energy['Country'].replace(to_replace="United States of America", value="United States",regex=False)
energy['Country'] = energy['Country'].replace(to_replace="United Kingdom of Great Britain and Northern Ireland", value="United Kingdom",regex=False)
energy['Country'] = energy['Country'].replace(to_replace="China, Hong Kong Special Administrative Region", value="Hong Kong",regex=False)

# %%
# Remove Special Charachters and numbrs from countries names:
# Replace the values with only the part before the parentheses
energy['Country'] = energy['Country'].str.split('(').str[0].str.strip()
energy['Country'] = energy['Country'].replace(regex={r"[^A-Za-z ]": ""} ).replace('', np.nan, regex=False)

# %%
# Validate the replacement:
# energy[energy['Country'] == 'United States of America']
energy[energy['Country'] == 'United States']
# Out:
#            Country  Energy Supply  Energy Supply per Capita  % Renewable
# 216  United States   9.083800e+10                     286.0     11.57098

# %%
energy["Country"].values
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'China Hong Kong Special Administrative Region',
#        'China Macao Special Administrative Region', 'Colombia', 'Comoros',
#        'Congo', 'Cook Islands', 'Costa Rica', 'Cte dIvoire', 'Croatia',
#        'Cuba', 'Curaao', 'Cyprus', 'Czech Republic',
#        'Democratic Peoples Republic of Korea',
# ...

# %%
energy.head()
# Out:
#           Country  Energy Supply  Energy Supply per Capita  % Renewable
# 0     Afghanistan   3.210000e+08                      10.0    78.669280
# 1         Albania   1.020000e+08                      35.0   100.000000
# 2         Algeria   1.959000e+09                      51.0     0.551010
# 3  American Samoa            NaN                       NaN     0.641026
# 4         Andorra   9.000000e+06                     121.0    88.695650

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### Step 1
# Next, load the GDP data from the file world_bank.csv, which is a csv containing countries' GDP from 1960 to 2015 from World Bank. Call this DataFrame GDP.
#
# Make sure to skip the header, and rename the following list of countries:
#
# "Korea,
# "Iran, Islamic Rep.": "Iran",
# "Hong Kong SAR, China": "Hong Kong"```

# %%
# Load GDP data:
GDP = pd.read_csv('world_bank.csv', skiprows=4)

# %%
GDP.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 60 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            119 non-null    float64
#  5   1961            120 non-null    float64
#  6   1962            120 non-null    float64
#  7   1963            120 non-null    float64
#  8   1964            120 non-null    float64
#  9   1965            127 non-null    float64
#  10  1966            132 non-null    float64
#  11  1967            133 non-null    float64
#  12  1968            137 non-null    float64
#  13  1969            137 non-null    float64
#  14  1970            146 non-null    float64
#  15  1971            146 non-null    float64
#  16  1972            146 non-null    float64
# ...

# %%
GDP.drop(columns=["Indicator Name", "Indicator Code"])
# Out:
#          Country Name Country Code          1960          1961          1962  \
# 0               Aruba          ABW           NaN           NaN           NaN
# 1             Andorra          AND           NaN           NaN           NaN
# 2         Afghanistan          AFG           NaN           NaN           NaN
# 3              Angola          AGO           NaN           NaN           NaN
# 4             Albania          ALB           NaN           NaN           NaN
# ..                ...          ...           ...           ...           ...
# 259       Yemen, Rep.          YEM           NaN           NaN           NaN
# 260      South Africa          ZAF  7.707081e+10  8.003449e+10  8.497844e+10
# 261  Congo, Dem. Rep.          COD  1.508024e+10  1.344383e+10  1.629401e+10
# 262            Zambia          ZMB  4.592975e+09  4.655503e+09  4.539542e+09
# 263          Zimbabwe          ZWE  3.338344e+09  3.549199e+09  3.600111e+09
#
# ...

# %%
# Drop the columns that is nit needed (Keep just last 10 years):
GDP.drop(GDP.columns[2:-10], axis = 1, inplace = True)

# %%
# Rename the required countries:
GDP['Country Name'] = GDP['Country Name'].replace("Korea, Rep.", "South Korea")
GDP['Country Name'] = GDP['Country Name'].replace("Iran, Islamic Rep.", "Iran")
GDP['Country Name'] = GDP['Country Name'].replace("Hong Kong SAR, China", "Hong Kong")

# %%
GDP['Country Name'].unique()
# Out:
# array(['Aruba', 'Andorra', 'Afghanistan', 'Angola', 'Albania',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Rep.',
#        'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria',
# ...

# %% [markdown]
# ### Step 2
#
# Finally, load the [http://www.scimagojr.com/countryrank.php?category=2102](Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology) from the file scimagojr-3.xlsx, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame ScimEn.

# %%
# Load the data:
ScimEn = pd.read_excel('scimagojr-3.xlsx')

# %%
# Check the data:
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %% [markdown]
# ### Step 3
# - Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
# - The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'].
# - This step should yield a data frame with 20 columns and 15 entries.

# %%
GDP.rename(columns={"Country Name": "Country"}, inplace=True)

# %%
# Merge all dataframes:


merged_first= pd.merge(energy, ScimEn, on='Country', how= 'inner')
merged_final = pd.merge(merged_first, GDP, on='Country', how= 'inner')

# %%
merged_final.head(30)
# Out:
#                    Country  Energy Supply  Energy Supply per Capita  \
# 0              Afghanistan   3.210000e+08                      10.0
# 1                  Albania   1.020000e+08                      35.0
# 2                  Algeria   1.959000e+09                      51.0
# 3           American Samoa            NaN                       NaN
# 4                  Andorra   9.000000e+06                     121.0
# 5                   Angola   6.420000e+08                      27.0
# 6      Antigua and Barbuda   8.000000e+06                      84.0
# 7                Argentina   3.378000e+09                      79.0
# 8                  Armenia   1.430000e+08                      48.0
# 9                Australia   5.386000e+09                     231.0
# 10                 Austria   1.391000e+09                     164.0
# 11              Azerbaijan   5.670000e+08                      60.0
# 12                 Bahrain   5.740000e+08                     425.0
# ...

# %%
merged_final.shape
# Out:
# (161, 22)

# %%
# Set the country as the index of the final merged dataframe:
merged_final.set_index('Country', inplace= True)

# %%
# sort the countries based on thier rank
merged_final = merged_final.sort_values(by = 'Rank')

# %%
merged_final
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0     19.75491
# United States        9.083800e+10                     286.0     11.57098
# Japan                1.898400e+10                     149.0     10.23282
# United Kingdom       7.920000e+09                     124.0     10.60047
# Russian Federation   3.070900e+10                     214.0     17.28868
# ...                           ...                       ...          ...
# Maldives             1.500000e+07                      43.0      0.00000
# Belize               1.300000e+07                      39.0     64.69003
# Palau                3.000000e+06                     152.0     18.75000
# Guyana               3.400000e+07                      45.0      0.00000
# Mauritania           5.100000e+07                      13.0      0.00000
#
#                     Rank  Documents  Citable documents  Citations  \
# Country
# ...

# %%
# filter the Top 15 country:
merged_final_15 = merged_final.iloc[:15]

# %%
merged_final_15
# Out:
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# United States        9.083800e+10                     286.0    11.570980
# Japan                1.898400e+10                     149.0    10.232820
# United Kingdom       7.920000e+09                     124.0    10.600470
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# ...

# %%
merged_final_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, China to Brazil
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Energy Supply             15 non-null     float64
#  1   Energy Supply per Capita  15 non-null     float64
#  2   % Renewable               15 non-null     float64
#  3   Rank                      15 non-null     int64
#  4   Documents                 15 non-null     int64
#  5   Citable documents         15 non-null     int64
#  6   Citations                 15 non-null     int64
#  7   Self-citations            15 non-null     int64
#  8   Citations per document    15 non-null     float64
#  9   H index                   15 non-null     int64
#  10  Country Code              15 non-null     object
#  11  2006                      15 non-null     float64
#  12  2007                      15 non-null     float64
# ...

# %% [markdown]
# ### Step 4
# The previous question joined three datasets then reduced this to just the top 15 entries. When you joined the datasets, but before you reduced this to the top 15 items, how many entries did you lose?
#
# This step should yield a single number.

# %%
# Find the diference between the length of the dataframe before filtring and after filtering
# This calculation with find how mant rows of data lost
data_lost = len(merged_final) - len(merged_final_15)
data_lost
# Out:
# 146

# %% [markdown]
# ### Step 5
# Answer the following questions in the context of only the top 15 countries by Scimagojr Rank
# 1. What is the average GDP over the last 10 years for each country? (Exclude missing values from this calculation.)
#         ◦ This step should return a Series named avgGDP with 15 countries and their average GDP sorted in descending order.
# 2. What is the mean Energy Supply per Capita?
#         ◦ This step should return a single number.
# 3. What country has the maximum % Renewable and what is the percentage?
#         ◦ This step should return a tuple with the name of the country and the percentage.

# %%
merged_final_15['avgGDP'] = merged_final_15.iloc[:, 11:].mean(axis = 1)
# Out:
# /tmp/ipykernel_308746/1056415683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_final_15['avgGDP'] = merged_final_15.iloc[:, 11:].mean(axis = 1)

# %%
merged_final_15['avgGDP'].sort_values(ascending=False)
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# Name: avgGDP, dtype: float64

# %%
# What is the mean Energy Supply per Capita?
merged_final_15['Energy Supply per Capita'].mean()
# Out:
# 157.6

# %%
# What country has the maximum % Renewable and what is the percentage?
(merged_final_15['% Renewable'].idxmax(), merged_final_15['% Renewable'].max())
# Out:
# ('Brazil', 69.64803)

# %% [markdown]
# ### Step 6
# - Create a new column that is the ratio of Self-Citations to Total Citations. What is the maximum value for this new column, and what country has the highest ratio?
# >This step should return a tuple with the name of the country and the ratio.

# %%
# Create the new column:
merged_final_15['ratio']= merged_final_15['Self-citations'] / merged_final_15['Citations']

# Check the data:
merged_final_15['ratio']
# Out:
# /tmp/ipykernel_308746/3119683807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_final_15['ratio']= merged_final_15['Self-citations'] / merged_final_15['Citations']
# Country
# China                 0.689313
# United States         0.335031
# Japan                 0.275997
# United Kingdom        0.183773
# Russian Federation    0.362517
# Canada                0.190369
# Germany               0.195111
# India                 0.288973
# France                0.218943
# South Korea           0.197035
# Italy                 0.238364
# Spain                 0.194299
# Iran                  0.332782
# Australia             0.171939
# Brazil                0.237159
# Name: ratio, dtype: float64

# %%
# Return the max ration and the country name in a tuple:
(merged_final_15['ratio'].idxmax(), merged_final_15['ratio'].max())
# Out:
# ('China', 0.6893126179389422)

# %% [markdown]
# ### Step 7
# - Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
# > This step should return a series named HighRenew whose index is the country name sorted in ascending order of rank.

# %%
# Find the % Renewable median:
renewale_median= merged_final_15['% Renewable'].median()

# %%
# Create the column and assign values:
# Assin 1 if the country's % Renewable value is at or above the median for all countries in the top 15
# Assign 0 otherwise

merged_final_15['HighRenew'] = (merged_final_15['% Renewable'] >= renewale_median).astype(int)
# Out:
# /tmp/ipykernel_308746/1658283739.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_final_15['HighRenew'] = (merged_final_15['% Renewable'] >= renewale_median).astype(int)

# %%
merged_final_15['HighRenew']
# Out:
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                1
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %% [markdown]
# ### Step 10
# - Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
#
# ```JSON
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```
# - This function should return a DataFrame with index named Continent
# ```
# ['Asia', 'Australia', 'Europe', 'North America', 'South America']
# ``` and columns ```['size', 'sum', 'mean', 'std']```

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
# Find the contiont for each country based on the givin dictionary:
merged_final_15['Continent'] = merged_final_15.index.map(lambda x: ContinentDict.get(x))
merged_final_15['Continent']
# Out:
# /tmp/ipykernel_308746/1070873518.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_final_15['Continent'] = merged_final_15.index.map(lambda x: ContinentDict.get(x))
# Country
# China                          Asia
# United States         North America
# Japan                          Asia
# United Kingdom               Europe
# Russian Federation           Europe
# Canada                North America
# Germany                      Europe
# India                          Asia
# France                       Europe
# South Korea                    Asia
# Italy                        Europe
# Spain                        Europe
# Iran                           Asia
# Australia                 Australia
# ...

# %%
# Find the population:
merged_final_15['Population'] = merged_final_15['Energy Supply'] / merged_final_15['Energy Supply per Capita']
# Out:
# /tmp/ipykernel_308746/53818401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_final_15['Population'] = merged_final_15['Energy Supply'] / merged_final_15['Energy Supply per Capita']

# %%
merged_final_15['Population']
# Out:
# Country
# China                 1.367645e+09
# United States         3.176154e+08
# Japan                 1.274094e+08
# United Kingdom        6.387097e+07
# Russian Federation    1.435000e+08
# Canada                3.523986e+07
# Germany               8.036970e+07
# India                 1.276731e+09
# France                6.383735e+07
# South Korea           4.980543e+07
# Italy                 5.990826e+07
# Spain                 4.644340e+07
# Iran                  7.707563e+07
# Australia             2.331602e+07
# Brazil                2.059153e+08
# Name: Population, dtype: float64

# %%
# Find the required statistics based on the population:

merged_final_15.groupby('Continent').agg({'Population': ['count', "sum", "mean", "std"]})
# Out:
#               Population
#                    count           sum          mean           std
# Continent
# Asia                   5  2.898666e+09  5.797333e+08  6.790979e+08
# Australia              1  2.331602e+07  2.331602e+07           NaN
# Europe                 6  4.579297e+08  7.632161e+07  3.464767e+07
# North America          2  3.528552e+08  1.764276e+08  1.996696e+08
# South America          1  2.059153e+08  2.059153e+08           NaN
